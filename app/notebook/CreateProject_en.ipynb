# %% [markdown]
# # ***Create Project***

# %% [markdown]
# ### 1. Enter the analysis project name as in the example
# - Example: projectdir = "new_analysis" <br>
#         → A folder named "new_analysis" will be created
# - Do not include spaces
# - Do not use existing folder names

# %%
import shutil

# %%
projectdir = "new_analysis"

# %% [markdown]
# ### 2. Execute RUN ALL (▶▶) at the top of this notebook
# When starting a project, necessary files will be copied from the template.

# %%
shutil.copytree('./template/en', f'./project/{projectdir}')

# %% [markdown]
# ### 3. Please move to the created project folder and execute the notebook
# - Do not move the created project folder. Errors may occur in the notebook if you do.
